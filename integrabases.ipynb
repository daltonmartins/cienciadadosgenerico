# %%
import pandas as pd
import glob # biblioteca para leitura de arquivos em diretórios

# %%
dfmapeamento=pd.read_excel('mapeamento.xlsx')
def sjoin(x): return '||'.join(x[x.notnull()].astype(str)) #comando para unir os valores de colunas iguais separado por ||

# %%
for arquivo in glob.glob("./CSV/*.*"):
    df=pd.read_csv(arquivo,sep=None, engine="python") #comando que detecta o separados do CSV automaticamente
    nomescolunas=df.columns.tolist()
    
    print("**************************")
    print(arquivo)
    print()
    print("NOME DAS COLUNAS ANTES")
    print(nomescolunas)  
    
    
    for coluna in nomescolunas:
        resultado=dfmapeamento.loc[dfmapeamento['Metadados'] == coluna]
        if not(resultado.empty): #se a coluna for mapeada para DC, substitui na dataframe
            novacoluna=resultado['DC'].tolist()[0]
            df.rename(columns = {coluna: novacoluna}, inplace=True)
            print("Renomeando ", coluna, " para ",novacoluna)
        else: #se a coluna não for mapeada para DC, apaga a coluna no dataframe
            df.drop(columns=[coluna], inplace=True) #apaga a coluna
            print("Apagando ",coluna)
            
    print()
    df=df.groupby(level=0, axis=1).apply(lambda x: x.apply(sjoin, axis=1)) # agrupa as colunas e chama a função pelo lambda
    print("NOME DAS COLUNAS DEPOIS")
    nomescolunas=df.columns.tolist()
    print(nomescolunas) 
    arquivo=arquivo.strip("./CSV/").strip(".csv")
    df.to_csv(arquivo+'_DC'+".csv")
# Out:
# **************************
# ./CSV/ibram_museusibramgoias_museudeartesacradaboamorte.csv
#
# NOME DAS COLUNAS ANTES
# ['Altura', 'Autor', 'Classificação', 'Data de aquisição', 'Data de produção', 'Denominação', 'Document', 'Largura', 'Link do Item', 'Local de produção', 'Material', 'Modo de aquisição', 'Número de registro', 'Procedência', 'Resumo descritivo', 'Situação', 'Técnica', 'Título', 'Histórico/Observação', 'Outros números', 'Profundidade', 'Peso', 'Marcas/Inscrições', 'Diâmetro']
# Apagando  Altura
# Renomeando  Autor  para  Autor
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Data de aquisição  para  Data
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Document
# Apagando  Largura
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Material
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Apagando  Procedência
# Renomeando  Resumo descritivo  para  Descrição
# Apagando  Situação
# Renomeando  Técnica  para  Contribuidor/ colaborador
# Renomeando  Título  para  Título
# Apagando  Histórico/Observação
# Apagando  Outros números
# Apagando  Profundidade
# Apagando  Peso
# Apagando  Marcas/Inscrições
# Apagando  Diâmetro
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/funarte_acervosergiobrittodigital.csv
#
# NOME DAS COLUNAS ANTES
# ['Autor', 'Descrição', 'Desenho Livre', 'Document', 'Dossiê', 'Função Sérgio Britto', 'Link do Item', 'Local', 'Nome do material', 'Tipo de artigo', 'Título', 'Ano', 'Tipo de publicação', 'Elenco', 'Equipe Técnica', 'Veículo da publicação', 'Material de Divulgação', 'Número de páginas', 'Projeto Gráfico', 'Observação']
# Renomeando  Autor  para  Autor
# Apagando  Descrição
# Apagando  Desenho Livre
# Apagando  Document
# Renomeando  Dossiê  para  Assunto/ palavras-chave
# Apagando  Função Sérgio Britto
# Apagando  Link do Item
# Apagando  Local
# Apagando  Nome do material
# Renomeando  Tipo de artigo  para  Assunto/ palavras-chave
# Renomeando  Título  para  Título
# Renomeando  Ano  para  Data
# Renomeando  Tipo de publicação  para  Assunto/ palavras-chave
# Renomeando  Elenco  para  Contribuidor/ colaborador
# Renomeando  Equipe Técnica  para  Contribuidor/ colaborador
# Renomeando  Veículo da publicação  para  Editor
# Apagando  Material de Divulgação
# Apagando  Número de páginas
# Apagando  Projeto Gráfico
# Apagando  Observação
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Editor', 'Título']
# **************************
# ./CSV/ibram_museusibramgoias_museucasadaprincesa.csv
#
# NOME DAS COLUNAS ANTES
# ['Autor', 'Classificação', 'Código Thesaurus', 'Data de aquisição', 'Data de produção', 'Denominação', 'Diâmetro', 'Document', 'Link do Item', 'Local de produção', 'Material', 'Modo de aquisição', 'Número de registro', 'Procedência', 'Profundidade', 'Resumo descritivo', 'Situação', 'Técnica', 'Marcas/Inscrições', 'Título', 'Histórico/Observação']
# Renomeando  Autor  para  Autor
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Código Thesaurus  para  Identifier
# Renomeando  Data de aquisição  para  Data
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Diâmetro
# Apagando  Document
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Material
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Apagando  Procedência
# Apagando  Profundidade
# Renomeando  Resumo descritivo  para  Descrição
# Apagando  Situação
# Renomeando  Técnica  para  Contribuidor/ colaborador
# Apagando  Marcas/Inscrições
# Renomeando  Título  para  Título
# Apagando  Histórico/Observação
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/iphan_regioes_patrimonio_arqueologico.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffregião', 'região_descrição', 'cidade', 'cidade_título', 'cidade_descrição', 'cidade_imagens', 'cidade_descricao_imagens', 'cidade_link']
# Apagando  ﻿região
# Renomeando  região_descrição  para  Descrição
# Renomeando  cidade  para  Abrangência/ Cobertura
# Renomeando  cidade_título  para  Título
# Renomeando  cidade_descrição  para  Descrição
# Apagando  cidade_imagens
# Renomeando  cidade_descricao_imagens  para  Descrição
# Apagando  cidade_link
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Descrição', 'Título']
# **************************
# ./CSV/funarte_cedoc.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffLink do Item', '"Com"', 'Assuntos', 'Classificação', 'Desc. física', 'Ent. princ.', 'Ent. sec.', 'Gerais', 'Imprenta', 'Inf. publicação', 'Link do título', 'Notação', 'Título', 'Escala mat. gráfico', 'Edição', 'Série', 'Conteúdo', 'Descrição principal', 'Locais 1', 'Público-alvo', 'Locais', 'Bibliográficas', 'ISBN', 'Acesso restrito', 'Cobert. geográfica', 'Outros títulos', 'Íntegra (recorte digital)', 'Título não controlado', 'Idioma', 'Dissertação ou tese', 'Locais 2', 'Premiação', 'Inf. sobre a edição', 'Hist. de procedência', 'ISSN', 'Periodicidade', 'Dados de evento', 'Resumo', 'Título traduzido por instituição catalogada', 'Participantes', 'Qualidade de dados', 'Citação/referência', 'Suplemento', 'Pub. mat. descritos', 'Numeração', 'Fonte (Avulsa)', 'Título analítico fonte', 'Inf. documentação', 'Reprodução', 'Sistema', 'Biográficas/históricas', 'Exposição', 'Forma fís. adicional', 'Tipo de arquivo', 'Créd. de produção', 'Índice cum. e rem.', 'Título anterior ou variações', 'Encadernação', 'Caract. de arquivo', 'Local origin. e dup.', 'Título de rel. não específica', 'Título uniforme', 'Financiamento', 'Fonte de aquisição', 'Uso e produção', 'Id. de cópia/versão', 'Versão original', 'Inf. Progr. Estudo', 'Folha de S. Paulo', 'Relatório e período', 'Fonte da descrição', 'Título chave', 'Título anterior - absorvido em parte', 'Metodologia', 'Título outro', 'Título idioma original', 'Título anterior']
# Apagando  ﻿Link do Item
# Apagando  "Com"
# Renomeando  Assuntos  para  Assunto/ palavras-chave
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Desc. física  para  Descrição
# Apagando  Ent. princ.
# Apagando  Ent. sec.
# Apagando  Gerais
# Apagando  Imprenta
# Apagando  Inf. publicação
# Apagando  Link do título
# Apagando  Notação
# Renomeando  Título  para  Título
# Apagando  Escala mat. gráfico
# Apagando  Edição
# Apagando  Série
# Apagando  Conteúdo
# Renomeando  Descrição principal  para  Descrição
# Apagando  Locais 1
# Apagando  Público-alvo
# Apagando  Locais
# Apagando  Bibliográficas
# Renomeando  ISBN  para  Identifier
# Apagando  Acesso restrito
# Renomeando  Cobert. geográfica  para  Abrangência/ Cobertura
# Apagando  Outros títulos
# Apagando  Íntegra (recorte digital)
# Renomeando  Título não controlado  para  Título
# Renomeando  Idioma  para  Idioma
# Apagando  Dissertação ou tese
# Apagando  Locais 2
# Apagando  Premiação
# Renomeando  Inf. sobre a edição  para  Editor
# Apagando  Hist. de procedência
# Renomeando  ISSN  para  Identifier
# Apagando  Periodicidade
# Apagando  Dados de evento
# Renomeando  Resumo  para  Descrição
# Renomeando  Título traduzido por instituição catalogada  para  Título
# Renomeando  Participantes  para  Contribuidor/ colaborador
# Apagando  Qualidade de dados
# Renomeando  Citação/referência  para  Relação
# Apagando  Suplemento
# Apagando  Pub. mat. descritos
# Apagando  Numeração
# Renomeando  Fonte (Avulsa)  para  Fonte
# Renomeando  Título analítico fonte  para  Título
# Apagando  Inf. documentação
# Apagando  Reprodução
# Apagando  Sistema
# Apagando  Biográficas/históricas
# Apagando  Exposição
# Apagando  Forma fís. adicional
# Renomeando  Tipo de arquivo  para  Tipo do recurso
# Renomeando  Créd. de produção  para  Contribuidor/ colaborador
# Apagando  Índice cum. e rem.
# Renomeando  Título anterior ou variações  para  Título
# Apagando  Encadernação
# Renomeando  Caract. de arquivo  para  Descrição
# Apagando  Local origin. e dup.
# Renomeando  Título de rel. não específica  para  Título
# Renomeando  Título uniforme  para  Título
# Apagando  Financiamento
# Renomeando  Fonte de aquisição  para  Fonte
# Apagando  Uso e produção
# Renomeando  Id. de cópia/versão  para  Identifier
# Apagando  Versão original
# Apagando  Inf. Progr. Estudo
# Apagando  Folha de S. Paulo
# Apagando  Relatório e período
# Renomeando  Fonte da descrição  para  Fonte
# Renomeando  Título chave  para  Título
# Renomeando  Título anterior - absorvido em parte  para  Título
# Apagando  Metodologia
# Renomeando  Título outro  para  Título
# Renomeando  Título idioma original  para  Título
# Apagando  Título anterior
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Contribuidor/ colaborador', 'Descrição', 'Editor', 'Fonte', 'Identifier', 'Idioma', 'Relação', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/ibram_museusibramgoias_museudasbandeiras.csv
#
# NOME DAS COLUNAS ANTES
# ['Acervo', 'Altura', 'Autor', 'Categoria', 'Classificação', 'Coleção', 'Comprimento', 'Código Thesaurus', 'Data de aquisição', 'Data de produção', 'Denominação', 'Destaque no acervo', 'Document', 'Fonte de aquisição', 'Histórico/Observação', 'Largura', 'Link do Item', 'Local de produção', 'Marcas/Inscrições', 'Material', 'Modo de aquisição', 'Número de registro', 'Procedência', 'Resumo descritivo', 'Situação', 'Técnica', 'Título', 'Diâmetro', 'Tema', 'Outros números', 'Profundidade', 'Peso', 'Exposições']
# Apagando  Acervo
# Apagando  Altura
# Renomeando  Autor  para  Autor
# Renomeando  Categoria  para  Assunto/ palavras-chave
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  Comprimento
# Renomeando  Código Thesaurus  para  Identifier
# Renomeando  Data de aquisição  para  Data
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Destaque no acervo
# Apagando  Document
# Renomeando  Fonte de aquisição  para  Fonte
# Apagando  Histórico/Observação
# Apagando  Largura
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Marcas/Inscrições
# Apagando  Material
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Apagando  Procedência
# Renomeando  Resumo descritivo  para  Descrição
# Apagando  Situação
# Renomeando  Técnica  para  Contribuidor/ colaborador
# Renomeando  Título  para  Título
# Apagando  Diâmetro
# Renomeando  Tema  para  Assunto/ palavras-chave
# Apagando  Outros números
# Apagando  Profundidade
# Apagando  Peso
# Apagando  Exposições
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Fonte', 'Identifier', 'Título']
# **************************
# ./CSV/ibram_museudodiamante_objetosdemineracao.csv
#
# NOME DAS COLUNAS ANTES
# ['Description', 'Document', 'Link do Item', 'Title']
# Apagando  Description
# Apagando  Document
# Apagando  Link do Item
# Apagando  Title
#
# NOME DAS COLUNAS DEPOIS
# []
# **************************
# ./CSV/iphan_sicg_imaterial.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffNome', 'Condição', 'Categoria', 'Abrangência', 'UF', 'Município', 'Coordenada(s)_geográfica(s)', 'Quantidade_de_imagens', 'Quantidade_de_videos', 'Quantidade_de_audios', 'Descrição_do_bem_imaterial', 'Localização_específica', 'Ações_vinculados_Tipo', 'Ações_vinculados_Nome', 'Ações_vinculados_Instrumento', 'Ações_vinculados_Situação', 'Área_de_ocorrência_UF', 'Área_de_ocorrência_Municípios', 'Página']
# Apagando  ﻿Nome
# Apagando  Condição
# Renomeando  Categoria  para  Assunto/ palavras-chave
# Renomeando  Abrangência  para  Abrangência/ Cobertura
# Renomeando  UF  para  Abrangência/ Cobertura
# Renomeando  Município  para  Abrangência/ Cobertura
# Renomeando  Coordenada(s)_geográfica(s)  para  Abrangência/ Cobertura
# Apagando  Quantidade_de_imagens
# Apagando  Quantidade_de_videos
# Apagando  Quantidade_de_audios
# Renomeando  Descrição_do_bem_imaterial  para  Descrição
# Apagando  Localização_específica
# Renomeando  Ações_vinculados_Tipo  para  Assunto/ palavras-chave
# Renomeando  Ações_vinculados_Nome  para  Título
# Apagando  Ações_vinculados_Instrumento
# Apagando  Ações_vinculados_Situação
# Renomeando  Área_de_ocorrência_UF  para  Abrangência/ Cobertura
# Renomeando  Área_de_ocorrência_Municípios  para  Abrangência/ Cobertura
# Apagando  Página
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Descrição', 'Título']
# **************************
# ./CSV/fundacao_palmares_flickr.csv
#
# NOME DAS COLUNAS ANTES
# ['dateuploaded', 'description', 'id', 'originalformat', 'taken', 'title', 'url', 'views']
# Renomeando  dateuploaded  para  Data
# Renomeando  description  para  Descrição
# Renomeando  id  para  Identifier
# Renomeando  originalformat  para  Formato
# Apagando  taken
# Renomeando  title  para  Título
# Apagando  url
# Apagando  views
#
# NOME DAS COLUNAS DEPOIS
# ['Data', 'Descrição', 'Formato', 'Identifier', 'Título']
# **************************
# ./CSV/ibram_museuvictormeirelles_autores.csv
#
# NOME DAS COLUNAS ANTES
# ['Acervo no MVM', 'Biografia', 'Document', 'Link do Item', 'Nome', 'Outros nomes', 'Cidade de falecimento', 'Cidade de nascimento', 'Data de nascimento', 'Data do falecimento', 'Estado de falecimento', 'Estado de nascimento', 'Exposições', 'Pais de nascimento', 'País de falecimento', 'Bibliografia']
# Apagando  Acervo no MVM
# Apagando  Biografia
# Apagando  Document
# Apagando  Link do Item
# Apagando  Nome
# Apagando  Outros nomes
# Renomeando  Cidade de falecimento  para  Abrangência/ Cobertura
# Renomeando  Cidade de nascimento  para  Abrangência/ Cobertura
# Renomeando  Data de nascimento  para  Data
# Renomeando  Data do falecimento  para  Data
# Renomeando  Estado de falecimento  para  Abrangência/ Cobertura
# Renomeando  Estado de nascimento  para  Abrangência/ Cobertura
# Apagando  Exposições
# Renomeando  Pais de nascimento  para  Abrangência/ Cobertura
# Renomeando  País de falecimento  para  Abrangência/ Cobertura
# Apagando  Bibliografia
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Data']
# **************************
# ./CSV/biblioteca_nacional_digital.csv
#
# NOME DAS COLUNAS ANTES
# ['Assuntos', 'CDD', 'Custódia', 'Descrição original', 'Fonte', 'Gerais', 'HTM', 'Idioma', 'Imprenta', 'JPG', 'Link do Item', 'Link do título', 'Loc. original', 'Tipo de documento', 'Título', 'Título analítico fonte', 'Título não controlado', 'Resumo', 'Autor/Criador', 'Colaborador', 'Coleção', 'PDF', 'Periodicidade', 'Locais', 'Locais 5', 'Objeto digital', 'Série', 'Site', 'Biográficas/históricas', 'Forma fís. adicional', 'HMTL', 'Citação/referência', 'Dados de evento', 'Cartografia', 'Edição', '"Com"', 'HTML', 'Conteúdo', 'Forma do registro', 'Título uniforme', 'Fonte de aquisição', 'jpg', 'PDf', 'Título de rel. não específica', 'Locais 6', 'PDF OCR (95 MB)', 'PDF OCR (40 MB)', 'PDF OCR (105 MB)', 'PDF OCR (13 MB)', 'Locais 2', 'Outros títulos', 'Detalhes físicos', 'pdf', 'JGP', 'Título de parte', '[Detentos da "Pentonville Prison" em trabalhos de alvenaria', 'Título uniforme coletivo', 'HM', 'http://bndigital.bn.gov.br//acervo-digital/O-Missionario/873829', 'PDF (90MB)', 'http://bndigital.bn.gov.br//acervo-digital/Mensario-dos-Alfaiates/872776', 'http://objdigital.bn.br/objdigital2/acervo_digital/div_iconografia/icon1506285/icon1506285.html', 'http://objdigital.bn.br/objdigital2/acervo_digital/div_iconografia/icon1506285/icon1506285.jpg', 'Locais 1', 'Pub. mat. descritos', 'PDF (78MB)', 'PDF (76MB)', 'PDF (25MB)', 'PDF (7MB)', 'PDF (8MB)', 'PDF (30MB)', 'PDF (21MB)', 'Inf. documentação', 'JPEG', 'Fonte (Avulsa)', 'Exposição', 'Pdf', 'Título especial', 'htm', 'Título relacionado analítico não controlado', 'Condições de uso', 'Reprodução', 'Bibliográficas', 'ISBN', 'Sistema', 'Título paralelo/equiv.', 'Numeração', 'Título posterior - continuado por', 'Locais 7', 'Título anterior - continua', 'Título forma física adicional', 'Acesso restrito', 'Periodicidade anterior', 'Título supl. ou ed. especial', 'Título outro', 'Índice cum. e rem.', 'Título contínuo', 'Fonte da descrição', 'Título chave', 'Título chave abreviado', 'Material', 'Créd. de produção', 'Suplemento', 'HTM856', 'Tipo de arquivo', 'HMT', 'http://objdigital.bn.br/objdigital2/acervo_digital/div_obrasraras/or820178/or820178.pdf', 'Inf. sobre a edição', 'Título abreviado', 'Título traduzido por instituição catalogada', 'Título de capa', 'PDF (175MB)', 'Locais 4', 'Ligação de entrada', 'Meio eletrônico', 'ContentE', 'Locais 9', 'PDF (135MB)', 'PDF (100MB)', 'MID', 'mid', 'SID', 'PDF (60MB)', 'MidFlip', 'JPg', 'PDF OCR (63MB)', 'PDF (500MB)', 'PDF (210MB)', 'Galery', 'PDF (118mb)', 'DJVU', 'Locais 8', 'MP3', 'PDF OCR (47MB)', 'HTM (bookreader)', 'PDF OCR (10MB)', 'PDF (66MB)', 'contentE', 'PDF (96MB)', 'q tif', 'PDF (85MB)', 'PDG', 'Galeria', 'HTM (ContentE)', '733873', 'HTM (somente mapa)', 'JPG (somente mapa)', 'PDF (94MB)', 'AVI', 'html', 'Premiação', 'Imagem original - HTM', 'Imagem original - JPG', 'Imagem restaurada digitalmente - HTM', 'Imagem restaurada digitalmente - JPG', '0', 'PDF (93MB)', 'PG', 'Participantes', 'PDF (150MB)', 'PDF (80MB)', 'PDF (10MB)', 'PDF (230MB)', 'PDF (45MB)', 'PDF (5MB)', 'PDF (9MB)', 'PDF (32MB)', 'PDF (11MB)', 'PDF (12MB)', 'PDF (105MB)', 'PDF (15MB)', 'PDF (185MB)', 'PDF (95MB)', 'PDF (57MB)', 'PDF (22MB)', 'PDF (50MB)', 'PDF (23MB)', 'PDF (38MB)', 'PDF (220MB)', 'PDF (65MB)', 'PDF (75MB)', 'PDF (180MB)', 'PDF (28MB)', 'PDF (42MB)', 'PDF (18MB)', 'PDF (20MB)', 'PDF (189MB)', 'PDF (61MB)', 'PDF (113MB)', 'PDF (63MB)', 'PDF (125MB)', 'PDF (111MB)', 'PDF (68MB)', 'Escala mat. gráfico', 'PDF (55MB)', 'Versão original', 'PDF (120MB)', 'PDF (260MB)', 'Imagem restaurada digitalmente - HTML', 'ISSN', 'EPUB - Arquivo para download', 'HTm', 'Htm', 'Local origin. e dup.', 'HTN', 'JPF']
# Renomeando  Assuntos  para  Assunto/ palavras-chave
# Renomeando  CDD  para  Identifier
# Apagando  Custódia
# Renomeando  Descrição original  para  Descrição
# Renomeando  Fonte  para  Fonte
# Apagando  Gerais
# Apagando  HTM
# Renomeando  Idioma  para  Idioma
# Apagando  Imprenta
# Apagando  JPG
# Apagando  Link do Item
# Apagando  Link do título
# Apagando  Loc. original
# Renomeando  Tipo de documento  para  Assunto/ palavras-chave
# Renomeando  Título  para  Título
# Renomeando  Título analítico fonte  para  Título
# Renomeando  Título não controlado  para  Título
# Renomeando  Resumo  para  Descrição
# Renomeando  Autor/Criador  para  Autor
# Renomeando  Colaborador  para  Contribuidor/ colaborador
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  PDF
# Apagando  Periodicidade
# Apagando  Locais
# Apagando  Locais 5
# Apagando  Objeto digital
# Apagando  Série
# Apagando  Site
# Apagando  Biográficas/históricas
# Apagando  Forma fís. adicional
# Apagando  HMTL
# Renomeando  Citação/referência  para  Relação
# Apagando  Dados de evento
# Apagando  Cartografia
# Apagando  Edição
# Apagando  "Com"
# Apagando  HTML
# Apagando  Conteúdo
# Apagando  Forma do registro
# Renomeando  Título uniforme  para  Título
# Renomeando  Fonte de aquisição  para  Fonte
# Apagando  jpg
# Apagando  PDf
# Renomeando  Título de rel. não específica  para  Título
# Apagando  Locais 6
# Apagando  PDF OCR (95 MB)
# Apagando  PDF OCR (40 MB)
# Apagando  PDF OCR (105 MB)
# Apagando  PDF OCR (13 MB)
# Apagando  Locais 2
# Apagando  Outros títulos
# Renomeando  Detalhes físicos  para  Descrição
# Apagando  pdf
# Apagando  JGP
# Renomeando  Título de parte  para  Título
# Apagando  [Detentos da "Pentonville Prison" em trabalhos de alvenaria
# Renomeando  Título uniforme coletivo  para  Título
# Apagando  HM
# Apagando  http://bndigital.bn.gov.br//acervo-digital/O-Missionario/873829
# Apagando  PDF (90MB)
# Apagando  http://bndigital.bn.gov.br//acervo-digital/Mensario-dos-Alfaiates/872776
# Apagando  http://objdigital.bn.br/objdigital2/acervo_digital/div_iconografia/icon1506285/icon1506285.html
# Apagando  http://objdigital.bn.br/objdigital2/acervo_digital/div_iconografia/icon1506285/icon1506285.jpg
# Apagando  Locais 1
# Apagando  Pub. mat. descritos
# Apagando  PDF (78MB)
# Apagando  PDF (76MB)
# Apagando  PDF (25MB)
# Apagando  PDF (7MB)
# Apagando  PDF (8MB)
# Apagando  PDF (30MB)
# Apagando  PDF (21MB)
# Apagando  Inf. documentação
# Apagando  JPEG
# Renomeando  Fonte (Avulsa)  para  Fonte
# Apagando  Exposição
# Apagando  Pdf
# Renomeando  Título especial  para  Título
# Apagando  htm
# Renomeando  Título relacionado analítico não controlado  para  Título
# Renomeando  Condições de uso  para  Direitos
# Apagando  Reprodução
# Apagando  Bibliográficas
# Renomeando  ISBN  para  Identifier
# Apagando  Sistema
# Renomeando  Título paralelo/equiv.  para  Título
# Apagando  Numeração
# Renomeando  Título posterior - continuado por  para  Título
# Apagando  Locais 7
# Renomeando  Título anterior - continua  para  Título
# Renomeando  Título forma física adicional  para  Título
# Apagando  Acesso restrito
# Apagando  Periodicidade anterior
# Renomeando  Título supl. ou ed. especial  para  Título
# Renomeando  Título outro  para  Título
# Apagando  Índice cum. e rem.
# Renomeando  Título contínuo  para  Título
# Renomeando  Fonte da descrição  para  Fonte
# Renomeando  Título chave  para  Título
# Renomeando  Título chave abreviado  para  Título
# Apagando  Material
# Renomeando  Créd. de produção  para  Contribuidor/ colaborador
# Apagando  Suplemento
# Apagando  HTM856
# Renomeando  Tipo de arquivo  para  Tipo do recurso
# Apagando  HMT
# Apagando  http://objdigital.bn.br/objdigital2/acervo_digital/div_obrasraras/or820178/or820178.pdf
# Renomeando  Inf. sobre a edição  para  Editor
# Renomeando  Título abreviado  para  Título
# Renomeando  Título traduzido por instituição catalogada  para  Título
# Renomeando  Título de capa  para  Título
# Apagando  PDF (175MB)
# Apagando  Locais 4
# Apagando  Ligação de entrada
# Renomeando  Meio eletrônico  para  Tipo do recurso
# Apagando  ContentE
# Apagando  Locais 9
# Apagando  PDF (135MB)
# Apagando  PDF (100MB)
# Apagando  MID
# Apagando  mid
# Apagando  SID
# Apagando  PDF (60MB)
# Apagando  MidFlip
# Apagando  JPg
# Apagando  PDF OCR (63MB)
# Apagando  PDF (500MB)
# Apagando  PDF (210MB)
# Apagando  Galery
# Apagando  PDF (118mb)
# Apagando  DJVU
# Apagando  Locais 8
# Apagando  MP3
# Apagando  PDF OCR (47MB)
# Apagando  HTM (bookreader)
# Apagando  PDF OCR (10MB)
# Apagando  PDF (66MB)
# Apagando  contentE
# Apagando  PDF (96MB)
# Apagando  q tif
# Apagando  PDF (85MB)
# Apagando  PDG
# Apagando  Galeria
# Apagando  HTM (ContentE)
# Apagando  733873
# Apagando  HTM (somente mapa)
# Apagando  JPG (somente mapa)
# Apagando  PDF (94MB)
# Apagando  AVI
# Apagando  html
# Apagando  Premiação
# Apagando  Imagem original - HTM
# Apagando  Imagem original - JPG
# Apagando  Imagem restaurada digitalmente - HTM
# Apagando  Imagem restaurada digitalmente - JPG
# Apagando  0
# Apagando  PDF (93MB)
# Apagando  PG
# Renomeando  Participantes  para  Contribuidor/ colaborador
# Apagando  PDF (150MB)
# Apagando  PDF (80MB)
# Apagando  PDF (10MB)
# Apagando  PDF (230MB)
# Apagando  PDF (45MB)
# Apagando  PDF (5MB)
# Apagando  PDF (9MB)
# Apagando  PDF (32MB)
# Apagando  PDF (11MB)
# Apagando  PDF (12MB)
# Apagando  PDF (105MB)
# Apagando  PDF (15MB)
# Apagando  PDF (185MB)
# Apagando  PDF (95MB)
# Apagando  PDF (57MB)
# Apagando  PDF (22MB)
# Apagando  PDF (50MB)
# Apagando  PDF (23MB)
# Apagando  PDF (38MB)
# Apagando  PDF (220MB)
# Apagando  PDF (65MB)
# Apagando  PDF (75MB)
# Apagando  PDF (180MB)
# Apagando  PDF (28MB)
# Apagando  PDF (42MB)
# Apagando  PDF (18MB)
# Apagando  PDF (20MB)
# Apagando  PDF (189MB)
# Apagando  PDF (61MB)
# Apagando  PDF (113MB)
# Apagando  PDF (63MB)
# Apagando  PDF (125MB)
# Apagando  PDF (111MB)
# Apagando  PDF (68MB)
# Apagando  Escala mat. gráfico
# Apagando  PDF (55MB)
# Apagando  Versão original
# Apagando  PDF (120MB)
# Apagando  PDF (260MB)
# Apagando  Imagem restaurada digitalmente - HTML
# Renomeando  ISSN  para  Identifier
# Apagando  EPUB - Arquivo para download
# Apagando  HTm
# Apagando  Htm
# Apagando  Local origin. e dup.
# Apagando  HTN
# Apagando  JPF
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Descrição', 'Direitos', 'Editor', 'Fonte', 'Identifier', 'Idioma', 'Relação', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/funarte_videos.csv
#
# NOME DAS COLUNAS ANTES
# ['Agente', 'Descrição', 'Document', 'Link do Item', 'Título']
# Apagando  Agente
# Apagando  Descrição
# Apagando  Document
# Apagando  Link do Item
# Renomeando  Título  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Título']
# **************************
# ./CSV/iphan_videos.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffLEGENDAS', 'LINK_PAGINA', 'TÍTULOS', 'UF', 'URL']
# Apagando  ﻿LEGENDAS
# Apagando  LINK_PAGINA
# Renomeando  TÍTULOS  para  Título
# Renomeando  UF  para  Abrangência/ Cobertura
# Apagando  URL
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Título']
# **************************
# ./CSV/ibram_museuvillalobos_fotografias.csv
#
# NOME DAS COLUNAS ANTES
# ['Autor', 'Classificação', 'Data de produção', 'Denominação', 'Document', 'Estado de conservação', 'Link do Item', 'Local de produção', 'Modo de aquisição', 'Número de registro', 'Resumo descritivo', 'Título', 'Material/Técnica']
# Renomeando  Autor  para  Autor
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Document
# Apagando  Estado de conservação
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Renomeando  Resumo descritivo  para  Descrição
# Renomeando  Título  para  Título
# Apagando  Material/Técnica
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Data', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/iphan_regioes.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffregião', 'região_descrição', 'região_link_imagem', 'região_link', 'cidade', 'cidade_descrição', 'cidade_link_imagens', 'cidade_descricao_imagens', 'cidade_link']
# Apagando  ﻿região
# Renomeando  região_descrição  para  Descrição
# Apagando  região_link_imagem
# Apagando  região_link
# Renomeando  cidade  para  Abrangência/ Cobertura
# Renomeando  cidade_descrição  para  Descrição
# Apagando  cidade_link_imagens
# Renomeando  cidade_descricao_imagens  para  Descrição
# Apagando  cidade_link
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Descrição']
# **************************
# ./CSV/iphan_sicg_acao.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffNome', 'Tipo', 'Instrumento', 'Situação', 'Data início', 'Data fim', 'UF', 'Município', 'Coordenada(s) geográfica(s)', 'Quantidade de imagens', 'Quantidade de videos', 'Quantidade de audios', 'Início da análise final', 'Início da análise preliminar', 'Início da instrução técnica', 'Conclusão da análise final', 'Conclusão da análise preliminar', 'Conclusão da instrução técnica', 'Descrição', 'Localização_específica', 'Atividades_Tipo', 'Atividades_Nome', 'Bens_vinculados_Condição', 'Bens_vinculados_Nome', 'Bens_vinculados_Categoria', 'Bens_vinculados_Abrangência', 'Instituições_Partícipes_Condição', 'Instituições_Partícipes_Nome', 'Instituições_Partícipes_Tipo', 'Documentos_vinculados', 'Abrangência_UF', 'Abrangência_Municípios', 'Palavras-chave:', 'Links', 'Página']
# Apagando  ﻿Nome
# Renomeando  Tipo  para  Tipo do recurso
# Apagando  Instrumento
# Apagando  Situação
# Renomeando  Data início  para  Data
# Renomeando  Data fim  para  Data
# Renomeando  UF  para  Abrangência/ Cobertura
# Renomeando  Município  para  Abrangência/ Cobertura
# Renomeando  Coordenada(s) geográfica(s)  para  Abrangência/ Cobertura
# Apagando  Quantidade de imagens
# Apagando  Quantidade de videos
# Apagando  Quantidade de audios
# Apagando  Início da análise final
# Apagando  Início da análise preliminar
# Apagando  Início da instrução técnica
# Apagando  Conclusão da análise final
# Apagando  Conclusão da análise preliminar
# Apagando  Conclusão da instrução técnica
# Apagando  Descrição
# Apagando  Localização_específica
# Apagando  Atividades_Tipo
# Apagando  Atividades_Nome
# Apagando  Bens_vinculados_Condição
# Renomeando  Bens_vinculados_Nome  para  Título
# Renomeando  Bens_vinculados_Categoria  para  Assunto/ palavras-chave
# Renomeando  Bens_vinculados_Abrangência  para  Abrangência/ Cobertura
# Apagando  Instituições_Partícipes_Condição
# Apagando  Instituições_Partícipes_Nome
# Apagando  Instituições_Partícipes_Tipo
# Apagando  Documentos_vinculados
# Renomeando  Abrangência_UF  para  Abrangência/ Cobertura
# Renomeando  Abrangência_Municípios  para  Abrangência/ Cobertura
# Renomeando  Palavras-chave:  para  Assunto/ palavras-chave
# Apagando  Links
# Apagando  Página
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Data', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/biblioteca_nacional_sophiaacervo.csv
#
# NOME DAS COLUNAS ANTES
# ['Assuntos', 'Autoria', 'Classificação Dewey', 'Código', 'Descrição física', 'Edição', 'ISBN', 'Idioma', 'Imagem', 'Imagem_descricao', 'Link', 'Localização', 'Material', 'Publicação', 'Subtítulo', 'Título', 'Nota bibliográfica', 'Série', 'Nota geral', 'Título uniforme', 'Título especial', 'Nota da biblioteca', 'Notas locais 5', 'Nota "Com"', 'Nota de conteúdo', 'Outros títulos', 'Título outro', 'Nota de dissertação ou tese', 'Título uniforme coletivo', 'Notas locais 7', 'Título Adicional', 'Nota de citação/referência', 'Notas locais 9', 'Nota de histórico de procedência', 'Título de capa', 'Nota de idioma', 'Título paralelo/equiv.', 'Título de parte', 'Título relacionado analítico não controlado', 'Nota de localização de original e duplicata', 'Nota de uso e produção', 'Resumo', 'Título lombada', 'Nota de fonte de aquisição', 'Nota de versão original', 'Título sec. pag. rosto', 'Sites', 'Nota de acesso restrito', 'Notas locais 8', 'Nota de reprodução', 'Cartografia', 'Nota de suplemento', 'Notas locais 1', 'Tipo de Publicação Seriada', 'Nota de características de arquivo', 'Título cabeçalho', 'Nota de informação sobre a edição', 'Nota de público-alvo', 'Nota de exposição', 'Nota de publicação sobre material descrito', 'Nota de índice cumulativo e remissivo', 'Nota biográfica', 'Nota de premiação', 'Número de chamada', 'CDD', 'Coleção', 'Custódia', 'Descrição original', 'Imprenta', 'Link do Item', 'Link do título', 'Loc. original', 'PDF', 'Tipo de documento', 'Autor/Criador', 'HTM', 'JPG', 'Gerais', 'Colaborador', 'Site', 'HTML', 'Exposição', 'Título não controlado', 'PG', 'Pub. mat. descritos', 'Conteúdo', 'Objeto digital', 'Locais', 'Periodicidade', 'htm', 'Citação/referência', 'Fonte de aquisição', '"Com"', 'Título analítico fonte', 'JGP', 'Fonte', 'Locais 5', 'Nota de sistema', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107']
# Renomeando  Assuntos  para  Assunto/ palavras-chave
# Renomeando  Autoria  para  Autor
# Renomeando  Classificação Dewey  para  Identifier
# Renomeando  Código  para  Identifier
# Apagando  Descrição física
# Apagando  Edição
# Renomeando  ISBN  para  Identifier
# Renomeando  Idioma  para  Idioma
# Apagando  Imagem
# Renomeando  Imagem_descricao  para  Descrição
# Apagando  Link
# Renomeando  Localização  para  Abrangência/ Cobertura
# Apagando  Material
# Apagando  Publicação
# Renomeando  Subtítulo  para  Título
# Renomeando  Título  para  Título
# Apagando  Nota bibliográfica
# Apagando  Série
# Apagando  Nota geral
# Renomeando  Título uniforme  para  Título
# Renomeando  Título especial  para  Título
# Apagando  Nota da biblioteca
# Apagando  Notas locais 5
# Apagando  Nota "Com"
# Apagando  Nota de conteúdo
# Apagando  Outros títulos
# Renomeando  Título outro  para  Título
# Apagando  Nota de dissertação ou tese
# Renomeando  Título uniforme coletivo  para  Título
# Apagando  Notas locais 7
# Renomeando  Título Adicional  para  Título
# Apagando  Nota de citação/referência
# Apagando  Notas locais 9
# Apagando  Nota de histórico de procedência
# Renomeando  Título de capa  para  Título
# Apagando  Nota de idioma
# Renomeando  Título paralelo/equiv.  para  Título
# Renomeando  Título de parte  para  Título
# Renomeando  Título relacionado analítico não controlado  para  Título
# Apagando  Nota de localização de original e duplicata
# Apagando  Nota de uso e produção
# Renomeando  Resumo  para  Descrição
# Renomeando  Título lombada  para  Título
# Apagando  Nota de fonte de aquisição
# Apagando  Nota de versão original
# Renomeando  Título sec. pag. rosto  para  Título
# Apagando  Sites
# Apagando  Nota de acesso restrito
# Apagando  Notas locais 8
# Apagando  Nota de reprodução
# Apagando  Cartografia
# Apagando  Nota de suplemento
# Apagando  Notas locais 1
# Renomeando  Tipo de Publicação Seriada  para  Assunto/ palavras-chave
# Apagando  Nota de características de arquivo
# Renomeando  Título cabeçalho  para  Título
# Apagando  Nota de informação sobre a edição
# Apagando  Nota de público-alvo
# Apagando  Nota de exposição
# Apagando  Nota de publicação sobre material descrito
# Apagando  Nota de índice cumulativo e remissivo
# Apagando  Nota biográfica
# Apagando  Nota de premiação
# Renomeando  Número de chamada  para  Identifier
# Renomeando  CDD  para  Identifier
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  Custódia
# Renomeando  Descrição original  para  Descrição
# Apagando  Imprenta
# Apagando  Link do Item
# Apagando  Link do título
# Apagando  Loc. original
# Apagando  PDF
# Renomeando  Tipo de documento  para  Assunto/ palavras-chave
# Renomeando  Autor/Criador  para  Autor
# Apagando  HTM
# Apagando  JPG
# Apagando  Gerais
# Renomeando  Colaborador  para  Contribuidor/ colaborador
# Apagando  Site
# Apagando  HTML
# Apagando  Exposição
# Renomeando  Título não controlado  para  Título
# Apagando  PG
# Apagando  Pub. mat. descritos
# Apagando  Conteúdo
# Apagando  Objeto digital
# Apagando  Locais
# Apagando  Periodicidade
# Apagando  htm
# Renomeando  Citação/referência  para  Relação
# Renomeando  Fonte de aquisição  para  Fonte
# Apagando  "Com"
# Renomeando  Título analítico fonte  para  Título
# Apagando  JGP
# Renomeando  Fonte  para  Fonte
# Apagando  Locais 5
# Apagando  Nota de sistema
# Apagando  Unnamed: 98
# Apagando  Unnamed: 99
# Apagando  Unnamed: 100
# Apagando  Unnamed: 101
# Apagando  Unnamed: 102
# Apagando  Unnamed: 103
# Apagando  Unnamed: 104
# Apagando  Unnamed: 105
# Apagando  Unnamed: 106
# Apagando  Unnamed: 107
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Descrição', 'Fonte', 'Identifier', 'Idioma', 'Relação', 'Título']
# **************************
# ./CSV/iphan_acervodigital.csv
#
# NOME DAS COLUNAS ANTES
# ['Assunto', 'Descrição do documento', 'Localização Geográfica', 'Palavras-chave', 'Tipo de documento', 'autor', 'data', 'descrição', 'link', 'titulo', 'Outros nomes', 'Número do documento']
# Renomeando  Assunto  para  Assunto/ palavras-chave
# Renomeando  Descrição do documento  para  Descrição
# Renomeando  Localização Geográfica  para  Abrangência/ Cobertura
# Renomeando  Palavras-chave  para  Assunto/ palavras-chave
# Renomeando  Tipo de documento  para  Assunto/ palavras-chave
# Apagando  autor
# Apagando  data
# Renomeando  descrição  para  Descrição
# Apagando  link
# Renomeando  titulo  para  Título
# Apagando  Outros nomes
# Renomeando  Número do documento  para  Identifier
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/funarte_artistasdobrasil.csv
#
# NOME DAS COLUNAS ANTES
# ['Acervo', 'Agente', 'Classificação', 'Descrição', 'Descrição Física', 'Document', 'Imprenta', 'Inf. publicação', 'Link do Item', 'Título', 'Assuntos', 'Conteúdo', 'Locais']
# Apagando  Acervo
# Apagando  Agente
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Apagando  Descrição
# Renomeando  Descrição Física  para  Descrição
# Apagando  Document
# Apagando  Imprenta
# Apagando  Inf. publicação
# Apagando  Link do Item
# Renomeando  Título  para  Título
# Renomeando  Assuntos  para  Assunto/ palavras-chave
# Apagando  Conteúdo
# Apagando  Locais
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Descrição', 'Título']
# **************************
# ./CSV/ibram_museuvictormeirelles_acervodomuseuvictormeirelles.csv
#
# NOME DAS COLUNAS ANTES
# ['Cidade de produção', 'Classificação', 'Data de aquisição', 'Data de produção/datação', 'Dimensões', 'Document', 'Estado de conservação', 'Estado de produção', 'Informações sobre o autor', 'Link do Item', 'Marcas/Inscrições', 'Material/Técnica', 'Modo de aquisição', 'Número de registro', 'País de produção', 'Procedência', 'Título', 'Data do 1º registro', 'Exposições', 'Catalogador', 'Notas sobre o estado de conservação', 'Denominação', 'Outros números', 'Estilos/Temas', 'Descrição de conteúdo', 'Resumo descritivo', 'Duração', 'Bibliografia']
# Renomeando  Cidade de produção  para  Abrangência/ Cobertura
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Data de aquisição  para  Data
# Renomeando  Data de produção/datação  para  Data
# Apagando  Dimensões
# Apagando  Document
# Apagando  Estado de conservação
# Renomeando  Estado de produção  para  Abrangência/ Cobertura
# Apagando  Informações sobre o autor
# Apagando  Link do Item
# Apagando  Marcas/Inscrições
# Apagando  Material/Técnica
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Renomeando  País de produção  para  Abrangência/ Cobertura
# Apagando  Procedência
# Renomeando  Título  para  Título
# Renomeando  Data do 1º registro  para  Data
# Apagando  Exposições
# Apagando  Catalogador
# Apagando  Notas sobre o estado de conservação
# Renomeando  Denominação  para  Título
# Apagando  Outros números
# Renomeando  Estilos/Temas  para  Assunto/ palavras-chave
# Renomeando  Descrição de conteúdo  para  Descrição
# Renomeando  Resumo descritivo  para  Descrição
# Apagando  Duração
# Apagando  Bibliografia
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Data', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/fundacao_palmares_html.csv
#
# NOME DAS COLUNAS ANTES
# ['Titulo/Descricao', 'Link_Imagem']
# Renomeando  Titulo/Descricao  para  Título
# Apagando  Link_Imagem
#
# NOME DAS COLUNAS DEPOIS
# ['Título']
# **************************
# ./CSV/ibram_museulasarsegall_ibram_koha.csv
#
# NOME DAS COLUNAS ANTES
# ['Assunto(s)', 'Em', 'Language', 'Recursos online', 'Tipo de conteúdo', 'Tipo de material', 'titulo', 'Gênero/Forma', 'Descrição', 'Por', 'Conteúdos', 'Nota ao pé da página ', 'O término do artigo, na página 38, aparece truncado entre dois títulos', 'Término de artigo em Cinearte, Rio de Janeiro, v. 4, n. 177, p. 6-7, 17 jul. 1929, que novamente aparece truncado entre dois títulos', 'Unnamed: 0', 'link_item', 'Supplemento de Cinearte ', 'A continuação do artigo se apresenta com o título de', 'Supplemento Cinearte ', 'Título no fim do número']
# Renomeando  Assunto(s)  para  Assunto/ palavras-chave
# Apagando  Em
# Renomeando  Language  para  Idioma
# Apagando  Recursos online
# Renomeando  Tipo de conteúdo  para  Assunto/ palavras-chave
# Renomeando  Tipo de material  para  Tipo do recurso
# Renomeando  titulo  para  Título
# Renomeando  Gênero/Forma  para  Assunto/ palavras-chave
# Apagando  Descrição
# Apagando  Por
# Apagando  Conteúdos
# Apagando  Nota ao pé da página
# Apagando  O término do artigo, na página 38, aparece truncado entre dois títulos
# Apagando  Término de artigo em Cinearte, Rio de Janeiro, v. 4, n. 177, p. 6-7, 17 jul. 1929, que novamente aparece truncado entre dois títulos
# Apagando  Unnamed: 0
# Apagando  link_item
# Apagando  Supplemento de Cinearte
# Apagando  A continuação do artigo se apresenta com o título de
# Apagando  Supplemento Cinearte
# Renomeando  Título no fim do número  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Idioma', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/iphan_regioes_bem_imaterial.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffregião', 'título', 'descrição', 'imagens', 'descricao_imagens', 'documnetos', 'url']
# Apagando  ﻿região
# Apagando  título
# Renomeando  descrição  para  Descrição
# Apagando  imagens
# Renomeando  descricao_imagens  para  Descrição
# Apagando  documnetos
# Apagando  url
#
# NOME DAS COLUNAS DEPOIS
# ['Descrição']
# **************************
# ./CSV/ibram_museudodiamante_tropeiros.csv
#
# NOME DAS COLUNAS ANTES
# ['Document', 'Link do Item', 'Numérico', 'Title']
# Apagando  Document
# Apagando  Link do Item
# Apagando  Numérico
# Apagando  Title
#
# NOME DAS COLUNAS DEPOIS
# []
# **************************
# ./CSV/casa_rui_barbosa_sophia_acervo.csv
#
# NOME DAS COLUNAS ANTES
# ['Assuntos', 'Desc. física', 'Ent. princ.', 'Imprenta', 'Link', 'Título', 'Unidade de descrição', 'Material', 'Ent. sec.', 'Título analítico fonte', 'Série', 'ISBN', 'Forma do registro', 'Edição', 'Título não controlado']
# Renomeando  Assuntos  para  Assunto/ palavras-chave
# Renomeando  Desc. física  para  Descrição
# Apagando  Ent. princ.
# Apagando  Imprenta
# Apagando  Link
# Renomeando  Título  para  Título
# Renomeando  Unidade de descrição  para  Descrição
# Apagando  Material
# Apagando  Ent. sec.
# Renomeando  Título analítico fonte  para  Título
# Apagando  Série
# Renomeando  ISBN  para  Identifier
# Apagando  Forma do registro
# Apagando  Edição
# Renomeando  Título não controlado  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/iphan_sicg_instituicao.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffNome', 'Condição', 'Tipo', 'UF', 'Município', 'Coordenada(s)_geográfica(s)', 'Contatos', 'Bens_vinculados_Condição', 'Bens_vinculados_Nome', 'Bens_vinculados_Categoria', 'Bens_vinculados_Abrangência', 'Ações_vinculados_Tipo', 'Ações_vinculados_Nome', 'Ações_vinculados_Instrumento', 'Ações_vinculados_Situação', 'Página']
# Apagando  ﻿Nome
# Apagando  Condição
# Renomeando  Tipo  para  Tipo do recurso
# Renomeando  UF  para  Abrangência/ Cobertura
# Renomeando  Município  para  Abrangência/ Cobertura
# Renomeando  Coordenada(s)_geográfica(s)  para  Abrangência/ Cobertura
# Apagando  Contatos
# Apagando  Bens_vinculados_Condição
# Renomeando  Bens_vinculados_Nome  para  Título
# Renomeando  Bens_vinculados_Categoria  para  Assunto/ palavras-chave
# Renomeando  Bens_vinculados_Abrangência  para  Abrangência/ Cobertura
# Renomeando  Ações_vinculados_Tipo  para  Assunto/ palavras-chave
# Renomeando  Ações_vinculados_Nome  para  Título
# Apagando  Ações_vinculados_Instrumento
# Apagando  Ações_vinculados_Situação
# Apagando  Página
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/funarte_edicoes.csv
#
# NOME DAS COLUNAS ANTES
# ['Coleção', 'Descrição da Coleção', 'Descrição do Livro', 'Document', 'Link do Item', 'Onde Comprar', 'Preço', 'Páginas', 'Título do Livro', 'Agente', 'Formato', 'ISBN']
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Renomeando  Descrição da Coleção  para  Descrição
# Renomeando  Descrição do Livro  para  Descrição
# Apagando  Document
# Apagando  Link do Item
# Apagando  Onde Comprar
# Apagando  Preço
# Apagando  Páginas
# Renomeando  Título do Livro  para  Título
# Apagando  Agente
# Renomeando  Formato  para  Formato
# Renomeando  ISBN  para  Identifier
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Descrição', 'Formato', 'Identifier', 'Título']
# **************************
# ./CSV/ibram_museuregionalcasadosottoni_acervomuseologico.csv
#
# NOME DAS COLUNAS ANTES
# ['Altura (cm)', 'Autor', 'Classificação', 'Condições de reprodução', 'Denominação', 'Document', 'Estado de conservação', 'Largura (cm)', 'Link do Item', 'Localização atual', 'Material', 'Modo de aquisição', 'Número de registro', 'Origem', 'Procedência', 'Profundidade (cm)', 'Situação', 'Técnica', 'Título', 'Data de aquisição', 'Armário/Estante/Mapoteca', 'Diâmetro (cm)', 'Prateleira/Gaveta', 'Andar', 'Comprimento (cm)', 'data de produção', 'Ano de produção', 'Condições de segurança', 'Nº anterior', 'Proteção legal', 'Conjunto com nº', 'Temas', 'Características técnicas', 'Características iconográficas/ornamentais', 'Características estilísticas', 'Espessura (cm)', 'Circunferência (cm)']
# Apagando  Altura (cm)
# Renomeando  Autor  para  Autor
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Condições de reprodução  para  Direitos
# Renomeando  Denominação  para  Título
# Apagando  Document
# Apagando  Estado de conservação
# Apagando  Largura (cm)
# Apagando  Link do Item
# Apagando  Localização atual
# Apagando  Material
# Apagando  Modo de aquisição
# Renomeando  Número de registro  para  Identifier
# Apagando  Origem
# Apagando  Procedência
# Apagando  Profundidade (cm)
# Apagando  Situação
# Renomeando  Técnica  para  Contribuidor/ colaborador
# Renomeando  Título  para  Título
# Renomeando  Data de aquisição  para  Data
# Apagando  Armário/Estante/Mapoteca
# Apagando  Diâmetro (cm)
# Apagando  Prateleira/Gaveta
# Apagando  Andar
# Apagando  Comprimento (cm)
# Apagando  data de produção
# Renomeando  Ano de produção  para  Data
# Apagando  Condições de segurança
# Renomeando  Nº anterior  para  Identifier
# Renomeando  Proteção legal  para  Direitos
# Renomeando  Conjunto com nº  para  Identifier
# Renomeando  Temas  para  Assunto/ palavras-chave
# Renomeando  Características técnicas  para  Descrição
# Renomeando  Características iconográficas/ornamentais  para  Descrição
# Renomeando  Características estilísticas  para  Descrição
# Apagando  Espessura (cm)
# Apagando  Circunferência (cm)
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Direitos', 'Identifier', 'Título']
# **************************
# ./CSV/ibram_webscrape_googlearts_belas_artes.csv
#
# NOME DAS COLUNAS ANTES
# ['colecao', 'link_item', 'Criador', 'Data', 'Tipo', 'Título', 'Dimensões físicas', 'Data de criação', 'Meio', 'Nº de registro', 'Autor', 'Coleção', 'Material/Técnica']
# Renomeando  colecao  para  Assunto/ palavras-chave
# Apagando  link_item
# Renomeando  Criador  para  Autor
# Renomeando  Data  para  Data
# Renomeando  Tipo  para  Tipo do recurso
# Renomeando  Título  para  Título
# Apagando  Dimensões físicas
# Renomeando  Data de criação  para  Data
# Apagando  Meio
# Renomeando  Nº de registro  para  Identifier
# Renomeando  Autor  para  Autor
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  Material/Técnica
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Autor', 'Data', 'Identifier', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/ibram_museudoouro_acervomuseologico.csv
#
# NOME DAS COLUNAS ANTES
# ['Autor', 'Características estilísticas', 'Características iconográficas/ornamentais', 'Características técnicas', 'Classificação', 'Condições de reprodução', 'Dados históricos', 'Data da fotografia', 'Data de produção', 'Denominação', 'Dimensões', 'Document', 'Esfera de proteção legal', 'Fotógrafo', 'Link do Item', 'Local de produção', 'Material/Técnica', 'Número de registro', 'Outros números', 'Palavras-chave', 'Procedência', 'Referências bibliográficas/arquivísticas', 'Resumo descritivo', 'Tipo de tombamento', 'Observações', 'Conjunto com nº', 'Título', 'Modo de aquisição', 'Data de aquisição', 'Marcas/Inscrições']
# Renomeando  Autor  para  Autor
# Renomeando  Características estilísticas  para  Descrição
# Renomeando  Características iconográficas/ornamentais  para  Descrição
# Renomeando  Características técnicas  para  Descrição
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Condições de reprodução  para  Direitos
# Apagando  Dados históricos
# Renomeando  Data da fotografia  para  Data
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Dimensões
# Apagando  Document
# Renomeando  Esfera de proteção legal  para  Direitos
# Renomeando  Fotógrafo  para  Contribuidor/ colaborador
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Material/Técnica
# Renomeando  Número de registro  para  Identifier
# Apagando  Outros números
# Renomeando  Palavras-chave  para  Assunto/ palavras-chave
# Apagando  Procedência
# Renomeando  Referências bibliográficas/arquivísticas  para  Relação
# Renomeando  Resumo descritivo  para  Descrição
# Apagando  Tipo de tombamento
# Apagando  Observações
# Renomeando  Conjunto com nº  para  Identifier
# Renomeando  Título  para  Título
# Apagando  Modo de aquisição
# Renomeando  Data de aquisição  para  Data
# Apagando  Marcas/Inscrições
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Direitos', 'Identifier', 'Relação', 'Título']
# **************************
# ./CSV/iphan_pergamun.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffAssuntos', 'Catalogação Pré MARC', 'Descrição Física', 'Entradas Secundárias/Autor', 'Entradas Secundárias/Série', 'Notas', 'Número de chamada', 'Publicação', 'Série', 'Título Principal', 'Unidade_de_Informação', 'Endereço Eletrônico', 'Autor Principal', 'ISBN', 'Edição', 'Outros Títulos', 'ISSN', 'Nota de conteúdo', 'Número de Chamada', 'Título Uniforme/Original', 'Coleção', 'Notas de Resumo', 'Notas Locais', 'Acesso Eletrônico', 'Local e Editora da Publicação', 'Localização do Artigo', 'Título do Artigo', 'Autor do Artigo', 'Freqüência da Publicação', 'Título Anterior', 'Título Chave/Abreviado']
# Apagando  ﻿Assuntos
# Apagando  Catalogação Pré MARC
# Renomeando  Descrição Física  para  Descrição
# Renomeando  Entradas Secundárias/Autor  para  Autor
# Apagando  Entradas Secundárias/Série
# Apagando  Notas
# Renomeando  Número de chamada  para  Identifier
# Apagando  Publicação
# Apagando  Série
# Renomeando  Título Principal  para  Título
# Apagando  Unidade_de_Informação
# Apagando  Endereço Eletrônico
# Renomeando  Autor Principal  para  Autor
# Renomeando  ISBN  para  Identifier
# Apagando  Edição
# Renomeando  Outros Títulos  para  Título
# Renomeando  ISSN  para  Identifier
# Apagando  Nota de conteúdo
# Apagando  Número de Chamada
# Renomeando  Título Uniforme/Original  para  Título
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  Notas de Resumo
# Apagando  Notas Locais
# Apagando  Acesso Eletrônico
# Renomeando  Local e Editora da Publicação  para  Editor
# Apagando  Localização do Artigo
# Renomeando  Título do Artigo  para  Título
# Renomeando  Autor do Artigo  para  Autor
# Apagando  Freqüência da Publicação
# Renomeando  Título Anterior  para  Título
# Renomeando  Título Chave/Abreviado  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Autor', 'Descrição', 'Editor', 'Identifier', 'Título']
# **************************
# ./CSV/funarte_musicanasamericas.csv
#
# NOME DAS COLUNAS ANTES
# ['Agente', 'Document', 'Link do Item', 'Tipo do Programa', 'Título', 'Data', 'Número do Programa']
# Apagando  Agente
# Apagando  Document
# Apagando  Link do Item
# Apagando  Tipo do Programa
# Renomeando  Título  para  Título
# Renomeando  Data  para  Data
# Apagando  Número do Programa
#
# NOME DAS COLUNAS DEPOIS
# ['Data', 'Título']
# **************************
# ./CSV/ibram_museuvictormeirelles_exposicoes.csv
#
# NOME DAS COLUNAS ANTES
# ['Data de abertura', 'Data de fechamento', 'Descrição', 'Document', 'Link do Item', 'Local', 'Local no prédio', 'Nome da exposição']
# Renomeando  Data de abertura  para  Data
# Renomeando  Data de fechamento  para  Data
# Apagando  Descrição
# Apagando  Document
# Apagando  Link do Item
# Apagando  Local
# Apagando  Local no prédio
# Apagando  Nome da exposição
#
# NOME DAS COLUNAS DEPOIS
# ['Data']
# **************************
# ./CSV/funarte_estudiof.csv
#
# NOME DAS COLUNAS ANTES
# ['Agente', 'Descrição', 'Document', 'Link do Item', 'Número do Programa', 'Título']
# Apagando  Agente
# Apagando  Descrição
# Apagando  Document
# Apagando  Link do Item
# Apagando  Número do Programa
# Renomeando  Título  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Título']
# **************************
# ./CSV/ibram_museunacionalbelasaartes_videos.csv
#
# NOME DAS COLUNAS ANTES
# ['link_item', 'titulo']
# Apagando  link_item
# Renomeando  titulo  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Título']
# **************************
# ./CSV/casa_rui_barbosa_oai.csv
#
# NOME DAS COLUNAS ANTES
# ['Unnamed: 0', '{http://purl.org/dc/elements/1.1/}creator', '{http://purl.org/dc/elements/1.1/}date', '{http://purl.org/dc/elements/1.1/}description', '{http://purl.org/dc/elements/1.1/}identifier', '{http://purl.org/dc/elements/1.1/}language', '{http://purl.org/dc/elements/1.1/}publisher', '{http://purl.org/dc/elements/1.1/}relation', '{http://purl.org/dc/elements/1.1/}subject', '{http://purl.org/dc/elements/1.1/}title', '{http://purl.org/dc/elements/1.1/}type', '{http://purl.org/dc/elements/1.1/}contributor', '{http://purl.org/dc/elements/1.1/}format', '{http://purl.org/dc/elements/1.1/}rights', '{http://purl.org/dc/elements/1.1/}source', '{http://purl.org/dc/elements/1.1/}coverage']
# Apagando  Unnamed: 0
# Renomeando  {http://purl.org/dc/elements/1.1/}creator  para  Autor
# Renomeando  {http://purl.org/dc/elements/1.1/}date  para  Data
# Renomeando  {http://purl.org/dc/elements/1.1/}description  para  Descrição
# Renomeando  {http://purl.org/dc/elements/1.1/}identifier  para  Identifier
# Renomeando  {http://purl.org/dc/elements/1.1/}language  para  Idioma
# Renomeando  {http://purl.org/dc/elements/1.1/}publisher  para  Editor
# Renomeando  {http://purl.org/dc/elements/1.1/}relation  para  Relação
# Renomeando  {http://purl.org/dc/elements/1.1/}subject  para  Assunto/ palavras-chave
# Renomeando  {http://purl.org/dc/elements/1.1/}title  para  Título
# Renomeando  {http://purl.org/dc/elements/1.1/}type  para  Tipo do recurso
# Renomeando  {http://purl.org/dc/elements/1.1/}contributor  para  Contribuidor/ colaborador
# Renomeando  {http://purl.org/dc/elements/1.1/}format  para  Formato
# Renomeando  {http://purl.org/dc/elements/1.1/}rights  para  Direitos
# Renomeando  {http://purl.org/dc/elements/1.1/}source  para  Fonte
# Renomeando  {http://purl.org/dc/elements/1.1/}coverage  para  Abrangência/ Cobertura
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Direitos', 'Editor', 'Fonte', 'Formato', 'Identifier', 'Idioma', 'Relação', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/iphan_sicg_material.csv
#
# NOME DAS COLUNAS ANTES
# ['\ufeffRecorte_territorial', 'Recorte_temático', 'Identificação_do_universo', 'UF', 'Município', 'CEP', 'Coordenada(s)_geográfica(s)', 'Endereço', 'Nome', 'Nome_popular', 'Natureza', 'Tipo', 'Estado_de_Conservação', 'Estado_de_Preservação', 'Uso_do_Solo', 'Entorno_do_bem', 'Síntese', 'Síntese_histórica', 'Meios_de_acesso_ao_bem', 'Outras_Informações', 'Investimento', 'Fiscalização_Autorização', 'Códigos_vinculados', 'Outras_localidades_vinculadas', 'Contato', 'Documentos', 'links_imagens', 'data-description_imagens', 'tilte_imagens', 'Página']
# Apagando  ﻿Recorte_territorial
# Renomeando  Recorte_temático  para  Assunto/ palavras-chave
# Renomeando  Identificação_do_universo  para  Identifier
# Renomeando  UF  para  Abrangência/ Cobertura
# Renomeando  Município  para  Abrangência/ Cobertura
# Apagando  CEP
# Renomeando  Coordenada(s)_geográfica(s)  para  Abrangência/ Cobertura
# Apagando  Endereço
# Apagando  Nome
# Apagando  Nome_popular
# Apagando  Natureza
# Renomeando  Tipo  para  Tipo do recurso
# Apagando  Estado_de_Conservação
# Apagando  Estado_de_Preservação
# Apagando  Uso_do_Solo
# Apagando  Entorno_do_bem
# Apagando  Síntese
# Apagando  Síntese_histórica
# Apagando  Meios_de_acesso_ao_bem
# Apagando  Outras_Informações
# Apagando  Investimento
# Apagando  Fiscalização_Autorização
# Renomeando  Códigos_vinculados  para  Identifier
# Renomeando  Outras_localidades_vinculadas  para  Abrangência/ Cobertura
# Apagando  Contato
# Apagando  Documentos
# Apagando  links_imagens
# Renomeando  data-description_imagens  para  Descrição
# Renomeando  tilte_imagens  para  Título
# Apagando  Página
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Descrição', 'Identifier', 'Tipo do recurso', 'Título']
# **************************
# ./CSV/funarte_brasilmemoriadasartes_audios.csv
#
# NOME DAS COLUNAS ANTES
# ['Agente', 'Coleção', 'Document', 'Faixa', 'Gênero', 'Link do Item', 'Título', 'Ano']
# Apagando  Agente
# Renomeando  Coleção  para  Assunto/ palavras-chave
# Apagando  Document
# Apagando  Faixa
# Renomeando  Gênero  para  Assunto/ palavras-chave
# Apagando  Link do Item
# Renomeando  Título  para  Título
# Renomeando  Ano  para  Data
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Data', 'Título']
# **************************
# ./CSV/casa_rui_barbosa_fotoweb_ext.csv
#
# NOME DAS COLUNAS ANTES
# ['Código da Imagem', 'Palavras Chave', 'Código de Referência', 'Fundo / Coleção', 'Setor de Origem', 'Autoria', 'Notas de Documento', 'Data da Imagem', 'Cidade', 'País', 'Qualidade da Imagem', 'Texto de Direitos Autorais', 'Prioridade', 'Tipo de Captura', 'Data de Criação', 'Origem da Imagem', 'Resolução em DPI', 'Extensão', 'Técnico', 'Titulo', 'Link']
# Renomeando  Código da Imagem  para  Identifier
# Renomeando  Palavras Chave  para  Assunto/ palavras-chave
# Renomeando  Código de Referência  para  Identifier
# Renomeando  Fundo / Coleção  para  Assunto/ palavras-chave
# Apagando  Setor de Origem
# Renomeando  Autoria  para  Autor
# Apagando  Notas de Documento
# Renomeando  Data da Imagem  para  Data
# Apagando  Cidade
# Renomeando  País  para  Abrangência/ Cobertura
# Apagando  Qualidade da Imagem
# Renomeando  Texto de Direitos Autorais  para  Direitos
# Apagando  Prioridade
# Apagando  Tipo de Captura
# Apagando  Data de Criação
# Apagando  Origem da Imagem
# Apagando  Resolução em DPI
# Renomeando  Extensão  para  Formato
# Renomeando  Técnico  para  Contribuidor/ colaborador
# Apagando  Titulo
# Apagando  Link
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Direitos', 'Formato', 'Identifier']
# **************************
# ./CSV/ibram_museuregionaldesaojoaodelrei_acervomuseologico.csv
#
# NOME DAS COLUNAS ANTES
# ['Altura (cm)', 'Autor', 'Características Estilísticas', 'Características Iconográficas/Ornamentais', 'Características técnicas', 'Classificação', 'Data de produção', 'Denominação', 'Document', 'Largura (cm)', 'Link do Item', 'Local de produção', 'Material', 'Número de registro', 'Profundidade (cm)', 'Resumo Descritivo', 'Técnica', 'Dados históricos', 'Referências Bibliográficas/Arquivísticas', 'Temas', 'Diâmetro (cm)', 'Título', 'Comprimento (cm)', 'Conjunto com n°', 'Marcas/Inscrições', 'Espessura (cm)', 'Peso (Kg)']
# Apagando  Altura (cm)
# Renomeando  Autor  para  Autor
# Apagando  Características Estilísticas
# Apagando  Características Iconográficas/Ornamentais
# Renomeando  Características técnicas  para  Descrição
# Renomeando  Classificação  para  Assunto/ palavras-chave
# Renomeando  Data de produção  para  Data
# Renomeando  Denominação  para  Título
# Apagando  Document
# Apagando  Largura (cm)
# Apagando  Link do Item
# Renomeando  Local de produção  para  Abrangência/ Cobertura
# Apagando  Material
# Renomeando  Número de registro  para  Identifier
# Apagando  Profundidade (cm)
# Apagando  Resumo Descritivo
# Renomeando  Técnica  para  Contribuidor/ colaborador
# Apagando  Dados históricos
# Apagando  Referências Bibliográficas/Arquivísticas
# Renomeando  Temas  para  Assunto/ palavras-chave
# Apagando  Diâmetro (cm)
# Renomeando  Título  para  Título
# Apagando  Comprimento (cm)
# Renomeando  Conjunto com n°  para  Identifier
# Apagando  Marcas/Inscrições
# Apagando  Espessura (cm)
# Apagando  Peso (Kg)
#
# NOME DAS COLUNAS DEPOIS
# ['Abrangência/ Cobertura', 'Assunto/ palavras-chave', 'Autor', 'Contribuidor/ colaborador', 'Data', 'Descrição', 'Identifier', 'Título']
# **************************
# ./CSV/funarte_edicoeson_line.csv
#
# NOME DAS COLUNAS ANTES
# ['Agente', 'Ano', 'Descrição', 'Document', 'ISBN', 'Link do Item', 'Palavras-chave', 'Título']
# Apagando  Agente
# Renomeando  Ano  para  Data
# Apagando  Descrição
# Apagando  Document
# Renomeando  ISBN  para  Identifier
# Apagando  Link do Item
# Renomeando  Palavras-chave  para  Assunto/ palavras-chave
# Renomeando  Título  para  Título
#
# NOME DAS COLUNAS DEPOIS
# ['Assunto/ palavras-chave', 'Data', 'Identifier', 'Título']

# %%
df
